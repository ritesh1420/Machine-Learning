# %%
import pandas as pd

# %%
series=pd.Series(["ritesh","bittu","suneeti"])
series
#series is 1-dimension
# Out:
# 0     ritesh
# 1      bittu
# 2    suneeti
# dtype: object

# %%
series=pd.Series({"ritesh","bittu","suneeti"})
series
#series is 1-dimension
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-3d9d4163617b> in <module>
# ----> 1 series=pd.Series({"ritesh","bittu","suneeti"})
#       2 series
#       3 #series is 1-dimension
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     334                 pass
#     335             elif isinstance(data, (set, frozenset)):
# --> 336                 raise TypeError(f"'{type(data).__name__}' type is unordered")
#     337             else:
#     338                 data = com.maybe_iterable_to_list(data)
#
# TypeError: 'set' type is unordered

# %%
col=pd.Series(["red","blue","white"])
print(col)
# Out:
# 0      red
# 1     blue
# 2    white
# dtype: object

# %%
#Data Fram is 2-dimentional 
data=pd.DataFrame(["name":['series'],"color fv":['col']])
data
# Out:
#   File "<ipython-input-9-dc5ac87542d4>", line 2
#     data=pd.DataFrame(["name":['series'],"color fv":['col']])
#                              ^
# SyntaxError: invalid syntax

# %%
#Data Fram is 2-dimentional 
data=pd.DataFrame(["name":series,"color fv":col])
data
#error

# %%
a=pd.Series(["hello"])
a

# %%
car_sales = pd.read_csv('car-sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#expoeting car_sales in another file
car_sales.to_csv("export_cars_sale.csv",index=False)
#index=False means it will not create extra index in copyed file

# %%
data=pd.read_csv('export_cars_sale.csv')
data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
data=pd.read_csv('export_cars_sale.csv',index=False)
data
#index=False shoud be in only during copy time

# %% [markdown]
# ## DESCRIBE DATA

# %%
#function
car_sales.to_csv()
# Out:
# ',Make,Colour,Odometer (KM),Doors,Price\r\n0,Toyota,White,150043,4,"$4,000.00"\r\n1,Honda,Red,87899,4,"$5,000.00"\r\n2,Toyota,Blue,32549,3,"$7,000.00"\r\n3,BMW,Black,11179,5,"$22,000.00"\r\n4,Nissan,White,213095,4,"$3,500.00"\r\n5,Toyota,Green,99213,4,"$4,500.00"\r\n6,Honda,Blue,45698,4,"$7,500.00"\r\n7,Honda,Blue,54738,4,"$7,000.00"\r\n8,Toyota,White,60000,4,"$6,250.00"\r\n9,Nissan,White,31600,4,"$9,700.00"\r\n'

# %%
#attribute
car_sale = pd.read_csv('car-sales.csv')
car_sale.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sale.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns=car_sale.columns
car_columns

# %%
car_sale.describe()
#it will not calulate any value of object
#in out file odometer and doors are int type 
#and other value are on object type
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sale.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sale["Doors"].sum()
# Out:
# 40

# %%
print(car_sale["Odometer (KM)"].mean())
# Out:
# 78601.4

# %%
car_sale["Doors","Odometer (KM)"].sum()#only one parameter
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Doors', 'Odometer (KM)')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-c7a705ceec2f> in <module>
# ...

# %%
data=pd.Series([88,99,9,4,8,"9"])#cannot add int int and char 
print(data)
data.sum()
# Out:
# 0    88
# 1    99
# 2     9
# 3     4
# 4     8
# 5     9
# dtype: object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-a1e1e2dfb8fe> in <module>
#       1 data=pd.Series([88,99,9,4,8,"9"])#cannot add int int and char
#       2 print(data)
# ----> 3 data.sum()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   11069             **kwargs,
#   11070         ):
# > 11071             return NDFrame.sum(
#   11072                 self, axis, skipna, level, numeric_only, min_count, **kwargs
#   11073             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10789         **kwargs,
#   10790     ):
# > 10791         return self._min_count_stat_function(
# ...

# %%
data=pd.Series([88,99,9,4,8,9])
print(data)
data.sum()
# Out:
# 0    88
# 1    99
# 2     9
# 3     4
# 4     8
# 5     9
# dtype: int64
# 217

# %% [markdown]
# ### VIEWING AND SELECTING DATA

# %%
import pandas as pd
car_sale=pd.read_csv('car-sales.csv')
car_sale.head()
#view some of row data for view perpose from top
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sale.head(1)
#1 for viewing only row one data
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00

# %%
print(car_sale.tail())


#for viewing data from down
print('............................................')

car_sale.tail(1)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00
# ............................................
#      Make Colour  Odometer (KM)  Doors      Price
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sale.loc[3]
#loc refer to index
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sale.iloc[3]
#iloc refer to position stating with 0
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animal=pd.Series(["cat","dog","ant","rat","tiger"],index=[0,3,5,7,9])
animal
# Out:
# 0      cat
# 3      dog
# 5      ant
# 7      rat
# 9    tiger
# dtype: object

# %%
print("at index number 3",animal.loc[3])

print("...................................")

print("at posion number 3",animal.iloc[3])
# Out:
# at index number 3 dog
# ...................................
# at posion number 3 rat

# %%
print(animal.iloc[:3])
print(">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>")
print(animal.loc[:3])
# Out:
# 0    cat
# 3    dog
# 5    ant
# dtype: object
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 0    cat
# 3    dog
# dtype: object

# %%
#both way is correct
print(car_sale["Make"])#also work with name with space in them

print("############################################")

print(car_sale.Make)#work ony if no space
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object
# ############################################
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
print(car_sale["Odometer (KM)"])

print("****************************************")

print(car_sale.Odometer (KM))
#error because of "Odometer (KM)"  has space in it
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64
# ****************************************
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-84ca778d8f34> in <module>
#       3 print("****************************************")
#       4
# ----> 5 print(car_sale.Odometer (KM))
#       6 #error because of "Odometer (KM)"  has space in it
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# ...

# %%
car_sale[car_sale["Make"]=="Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sale[car_sale["Odometer (KM)"]>100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sale["Make"],car_sale["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sale.groupby(['Make']).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sale.plot()
# Out:
# <AxesSubplot:>

# %%
car_sale["Odometer (KM)"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sale.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Odometer (KM)'}>,
#         <AxesSubplot:title={'center':'Doors'}>]], dtype=object)

# %%
car_sale["Odometer (KM)"].hist()
# Out:
# <AxesSubplot:>

# %%
#changing price object data type to int data type
car_sale["Price"] = car_sale["Price"].str.replace('[\$\,]|\.\d*', '').astype(int)
# Out:
# <ipython-input-42-19a2776ae7f9>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sale["Price"] = car_sale["Price"].str.replace('[\$\,]|\.\d*', '').astype(int)

# %%
car_sale["Price"]
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: int32

# %%
import pandas as pd
data=pd.read_csv('car-sales.csv')
#data
data.plot()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
data=pd.read_csv('car-sales.csv')
data['Doors'].plot()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
data=pd.read_csv('car-sales.csv')
data.to_csv('datacopyed.csv',index=False)
print('data copyed to datacopyed file ')
# Out:
# data copyed to datacopyed file

# %%
data['Make'].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
import pandas as pd
data=pd.read_csv('car-sales.csv')
data['Make']=data['Make'].str.lower()
data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  toyota  White         150043      4   $4,000.00
# 1   honda    Red          87899      4   $5,000.00
# 2  toyota   Blue          32549      3   $7,000.00
# 3     bmw  Black          11179      5  $22,000.00
# 4  nissan  White         213095      4   $3,500.00
# 5  toyota  Green          99213      4   $4,500.00
# 6   honda   Blue          45698      4   $7,500.00
# 7   honda   Blue          54738      4   $7,000.00
# 8  toyota  White          60000      4   $6,250.00
# 9  nissan  White          31600      4   $9,700.00

# %%
import pandas as pd
missing_data=pd.read_csv("car-sales-missing-data.csv")
missing_data
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
missing_data['Odometer'].mean()
# Out:
# 92302.66666666667

# %%
import pandas as pd
missing_data=pd.read_csv("car-sales-missing-data.csv")
missing_data['Odometer'].fillna(missing_data['Odometer'].mean())
#The fillna() method replaces the NULL values with a specified value. The fillna() 
#method returns a new DataFrame object unless the inplace parameter is set to True 
#in that case the fillna() method does the replacing in the original DataFrame instead.
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
missing_data#yet not filled in original data
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
missing_data['Odometer'].fillna(missing_data['Odometer'].mean(),inplace=True)
missing_data
#The 'inplace=True' argument stands for the data frame has to make changes permanent
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
# When inplace = True , the data is modified in place, 
which means it will return nothing and the dataframe is now updated.

# %%
import pandas as pd
data=pd.read_csv("car-sales.csv")
data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#colums for series
seat_colums=pd.Series(['5','5','5','5','5'])
data["Seats"]=seat_colums
data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Seats
# 0  Toyota  White         150043      4   $4,000.00     5
# 1   Honda    Red          87899      4   $5,000.00     5
# 2  Toyota   Blue          32549      3   $7,000.00     5
# 3     BMW  Black          11179      5  $22,000.00     5
# 4  Nissan  White         213095      4   $3,500.00     5
# 5  Toyota  Green          99213      4   $4,500.00   NaN
# 6   Honda   Blue          45698      4   $7,500.00   NaN
# 7   Honda   Blue          54738      4   $7,000.00   NaN
# 8  Toyota  White          60000      4   $6,250.00   NaN
# 9  Nissan  White          31600      4   $9,700.00   NaN

# %%
data["Seats"].fillna(9,inplace=False)
data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Seats
# 0  Toyota  White         150043      4   $4,000.00     5
# 1   Honda    Red          87899      4   $5,000.00     5
# 2  Toyota   Blue          32549      3   $7,000.00     5
# 3     BMW  Black          11179      5  $22,000.00     5
# 4  Nissan  White         213095      4   $3,500.00     5
# 5  Toyota  Green          99213      4   $4,500.00   NaN
# 6   Honda   Blue          45698      4   $7,500.00   NaN
# 7   Honda   Blue          54738      4   $7,000.00   NaN
# 8  Toyota  White          60000      4   $6,250.00   NaN
# 9  Nissan  White          31600      4   $9,700.00   NaN

# %%
fuel_rate=[6,4,4.5,8.9,45,57.5,3.7,34.5,7.8,6.8]
data['fuel per 100KM']=fuel_rate
data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Seats  total fuel used  \
# 0  Toyota  White         150043      4   $4,000.00     5         9002.580
# 1   Honda    Red          87899      4   $5,000.00     5         3515.960
# 2  Toyota   Blue          32549      3   $7,000.00     5         1464.705
# 3     BMW  Black          11179      5  $22,000.00     5          994.931
# 4  Nissan  White         213095      4   $3,500.00     5        95892.750
# 5  Toyota  Green          99213      4   $4,500.00   NaN        57047.475
# 6   Honda   Blue          45698      4   $7,500.00   NaN         1690.826
# 7   Honda   Blue          54738      4   $7,000.00   NaN        18884.610
# 8  Toyota  White          60000      4   $6,250.00   NaN         4680.000
# 9  Nissan  White          31600      4   $9,700.00   NaN         2148.800
#
#    pass road safty  fuel per 100KM
# 0             True             6.0
# 1             True             4.0
# 2             True             4.5
# ...

# %%
data['total fuel used']=data['Odometer (KM)']/100 * data['fuel per 100KM']
data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Seats  total fuel used  \
# 0  Toyota  White         150043      4   $4,000.00     5         9002.580
# 1   Honda    Red          87899      4   $5,000.00     5         3515.960
# 2  Toyota   Blue          32549      3   $7,000.00     5         1464.705
# 3     BMW  Black          11179      5  $22,000.00     5          994.931
# 4  Nissan  White         213095      4   $3,500.00     5        95892.750
# 5  Toyota  Green          99213      4   $4,500.00   NaN        57047.475
# 6   Honda   Blue          45698      4   $7,500.00   NaN         1690.826
# 7   Honda   Blue          54738      4   $7,000.00   NaN        18884.610
# 8  Toyota  White          60000      4   $6,250.00   NaN         4680.000
# 9  Nissan  White          31600      4   $9,700.00   NaN         2148.800
#
#    pass road safty  fuel per 100KM
# 0             True             6.0
# 1             True             4.0
# 2             True             4.5
# ...

# %%
When inplace = True , the data is modified in place,which means it will return nothing and the
dataframe is now updated.(it actually modify the data,and return nothing)

When inplace = False ,which is the default, then the operation is performed and it returns a copy of the object. 
You then need to save it to something.(it does not modify real data.it return copy of modify)

# %%
data.drop('fuel per 100KM',axis=1) #by default inplace=False
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Seats  total fuel used  \
# 0  Toyota  White         150043      4   $4,000.00     5         9002.580
# 1   Honda    Red          87899      4   $5,000.00     5         3515.960
# 2  Toyota   Blue          32549      3   $7,000.00     5         1464.705
# 3     BMW  Black          11179      5  $22,000.00     5          994.931
# 4  Nissan  White         213095      4   $3,500.00     5        95892.750
# 5  Toyota  Green          99213      4   $4,500.00   NaN        57047.475
# 6   Honda   Blue          45698      4   $7,500.00   NaN         1690.826
# 7   Honda   Blue          54738      4   $7,000.00   NaN        18884.610
# 8  Toyota  White          60000      4   $6,250.00   NaN         4680.000
# 9  Nissan  White          31600      4   $9,700.00   NaN         2148.800
#
#    pass road safty
# 0             True
# 1             True
# 2             True
# 3             True
# 4             True
# 5             True
# ...

# %%
data  #original data does not change
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Seats  total fuel used  \
# 0  Toyota  White         150043      4   $4,000.00     5         9002.580
# 1   Honda    Red          87899      4   $5,000.00     5         3515.960
# 2  Toyota   Blue          32549      3   $7,000.00     5         1464.705
# 3     BMW  Black          11179      5  $22,000.00     5          994.931
# 4  Nissan  White         213095      4   $3,500.00     5        95892.750
# 5  Toyota  Green          99213      4   $4,500.00   NaN        57047.475
# 6   Honda   Blue          45698      4   $7,500.00   NaN         1690.826
# 7   Honda   Blue          54738      4   $7,000.00   NaN        18884.610
# 8  Toyota  White          60000      4   $6,250.00   NaN         4680.000
# 9  Nissan  White          31600      4   $9,700.00   NaN         2148.800
#
#    pass road safty  fuel per 100KM
# 0             True             6.0
# 1             True             4.0
# 2             True             4.5
# ...

# %%
data["pass road safty"]=True
data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Seats  total fuel used  \
# 0  Toyota  White         150043      4   $4,000.00     5         9002.580
# 1   Honda    Red          87899      4   $5,000.00     5         3515.960
# 2  Toyota   Blue          32549      3   $7,000.00     5         1464.705
# 3     BMW  Black          11179      5  $22,000.00     5          994.931
# 4  Nissan  White         213095      4   $3,500.00     5        95892.750
# 5  Toyota  Green          99213      4   $4,500.00   NaN        57047.475
# 6   Honda   Blue          45698      4   $7,500.00   NaN         1690.826
# 7   Honda   Blue          54738      4   $7,000.00   NaN        18884.610
# 8  Toyota  White          60000      4   $6,250.00   NaN         4680.000
# 9  Nissan  White          31600      4   $9,700.00   NaN         2148.800
#
#    pass road safty  fuel per 100KM
# 0             True             6.0
# 1             True             4.0
# 2             True             4.5
# ...

# %%
data.drop('fuel per 100KM',axis=1,inplace=True)  #ture means modify real data

# %%
data #deleted fuel per 100KM colum parmamentaly
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Seats  total fuel used  \
# 0  Toyota  White         150043      4   $4,000.00     5         9002.580
# 1   Honda    Red          87899      4   $5,000.00     5         3515.960
# 2  Toyota   Blue          32549      3   $7,000.00     5         1464.705
# 3     BMW  Black          11179      5  $22,000.00     5          994.931
# 4  Nissan  White         213095      4   $3,500.00     5        95892.750
# 5  Toyota  Green          99213      4   $4,500.00   NaN        57047.475
# 6   Honda   Blue          45698      4   $7,500.00   NaN         1690.826
# 7   Honda   Blue          54738      4   $7,000.00   NaN        18884.610
# 8  Toyota  White          60000      4   $6,250.00   NaN         4680.000
# 9  Nissan  White          31600      4   $9,700.00   NaN         2148.800
#
#    pass road safty
# 0             True
# 1             True
# 2             True
# 3             True
# 4             True
# 5             True
# ...

# %%
sample_data=data.sample(frac=1)
#use for sample of data give random data 
#frac=fraction of data like 0.5 for half data 
sample_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Seats  total fuel used  \
# 1   Honda    Red          87899      4   $5,000.00     5         3515.960
# 0  Toyota  White         150043      4   $4,000.00     5         9002.580
# 8  Toyota  White          60000      4   $6,250.00   NaN         4680.000
# 6   Honda   Blue          45698      4   $7,500.00   NaN         1690.826
# 3     BMW  Black          11179      5  $22,000.00     5          994.931
# 5  Toyota  Green          99213      4   $4,500.00   NaN        57047.475
# 4  Nissan  White         213095      4   $3,500.00     5        95892.750
# 7   Honda   Blue          54738      4   $7,000.00   NaN        18884.610
# 9  Nissan  White          31600      4   $9,700.00   NaN         2148.800
# 2  Toyota   Blue          32549      3   $7,000.00     5         1464.705
#
#    pass road safty
# 1             True
# 0             True
# 8             True
# 6             True
# 3             True
# 5             True
# ...

# %%
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Seats  total fuel used  \
# 0  Toyota  White         150043      4   $4,000.00     5         9002.580
# 1   Honda    Red          87899      4   $5,000.00     5         3515.960
# 2  Toyota   Blue          32549      3   $7,000.00     5         1464.705
# 3     BMW  Black          11179      5  $22,000.00     5          994.931
# 4  Nissan  White         213095      4   $3,500.00     5        95892.750
# 5  Toyota  Green          99213      4   $4,500.00   NaN        57047.475
# 6   Honda   Blue          45698      4   $7,500.00   NaN         1690.826
# 7   Honda   Blue          54738      4   $7,000.00   NaN        18884.610
# 8  Toyota  White          60000      4   $6,250.00   NaN         4680.000
# 9  Nissan  White          31600      4   $9,700.00   NaN         2148.800
#
#    pass road safty
# 0             True
# 1             True
# 2             True
# 3             True
# 4             True
# 5             True
# ...

# %%
sample_data=data.sample(frac=0.5)
#use for "sample()" of data give random data 
#frac=fraction of data like 0.5 for half data 
sample_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Seats  total fuel used  \
# 9  Nissan  White          31600      4   $9,700.00   NaN         2148.800
# 1   Honda    Red          87899      4   $5,000.00     5         3515.960
# 5  Toyota  Green          99213      4   $4,500.00   NaN        57047.475
# 3     BMW  Black          11179      5  $22,000.00     5          994.931
# 8  Toyota  White          60000      4   $6,250.00   NaN         4680.000
#
#    pass road safty
# 9             True
# 1             True
# 5             True
# 3             True
# 8             True

# %%
sample_data.sample(frac=0.2)
# Out:
#    level_0  index    Make Colour  Odometer (KM)  Doors      Price Seats  \
# 2        2      0  Toyota  White         150043      4  $4,000.00     5
#
#    total fuel used  pass road safty
# 2          9002.58             True

# %%
print("=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+==+=+==============")
# Out:
# =+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+==+=+==============

# %%
sample_data.reset_index(inplace=True) #reset_index() for shorting accordingly
sample_data
# Out:
#    index    Make Colour  Odometer (KM)  Doors       Price Seats  \
# 0      9  Nissan  White          31600      4   $9,700.00   NaN
# 1      1   Honda    Red          87899      4   $5,000.00     5
# 2      5  Toyota  Green          99213      4   $4,500.00   NaN
# 3      3     BMW  Black          11179      5  $22,000.00     5
# 4      8  Toyota  White          60000      4   $6,250.00   NaN
#
#    total fuel used  pass road safty
# 0         2148.800             True
# 1         3515.960             True
# 2        57047.475             True
# 3          994.931             True
# 4         4680.000             True

# %%
import seaborn as sb
import matplotlib.pyplot as plot
import numpy as np
sb.set_style("whitegrid")
plot_omega = 2
plot1 = np.linspace(0, 10, 100)
plot2 = np.cos(plot_omega * plot1)
plot3 = np.sin(plot_omega * plot1)
plot.figure(figsize=(6,5))
plot_axis = plot.axes (projection = '3d')
plot_axis.plot3D (plot2, plot3, plot1)
plot.tight_layout ()
plot.show ()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def f(x, y):
    return np.sin(np.sqrt(x ** 4 + y ** 4))

x = np.linspace(-4, 4, 25)
y = np.linspace(-4, 4, 25)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 40, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

plt.show()

# %%
import pandas as pd
data=pd.read_csv("car-sales.csv")
data.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
data.rename(columns = {'Make':'MAKE','Colour':'COLOUR'}, inplace = True)

# %%
data.head()
# Out:
#      MAKE COLOUR  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
import pandas as pd
df=pd.DataFrame({"Name":['Tom','Nick','John','Peter'],
                 "Age":[15,26,17,28]})
df
# Out:
#     Name  Age
# 0    Tom   15
# 1   Nick   26
# 2   John   17
# 3  Peter   28

# %%
df.columns =['Col_1', 'Col_2']
df.index = ['Row1', 'Row2', 'Row3', 'Row4']

# %%
df
# Out:
#       Col_1  Col_2
# Row1    Tom     15
# Row2   Nick     26
# Row3   John     17
# Row4  Peter     28

# %%
df
# Out:
#       Col_1  Col_2
# Row1    Tom     15
# Row2   Nick     26
# Row3   John     17
# Row4  Peter     28
